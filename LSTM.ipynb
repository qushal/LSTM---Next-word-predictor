# %% [markdown]
# <a href="https://colab.research.google.com/github/qushal/LSTM---Next-word-predictor/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-631323f2-6435-4a18-8c4e-dff7b1b64187" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-631323f2-6435-4a18-8c4e-dff7b1b64187">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("chat_data.txt", "r", encoding = "utf-8") as f:
  text_data = f.read()

print(text_data[:500])
# Out:
# let’s play same here coffee? wish me luck netflix n chill guess what? let’s gooo 🚀 bro trust me done with dinner 100% pls stop send it rn can’t talk rn sure vacay mode at work beach 🏖️ gimme a sec nah brooo same here weekend vibes 😎 omw home cricket 🏏 pizza 🍕 pubg time football match wyd? good morning wait what nope same old basketball 🏀 ice cream 🍦 sunny mood ☀️ road trip 🚗 ugh monday again call u later hey u there? coming soon rainy day 🌧️ ikr good luck 🍀 yep office sucks lol meet u at 5 omg o

# %%
faqs = text_data[:5000]
faqs
# Out:
# 'let’s play same here coffee? wish me luck netflix n chill guess what? let’s gooo 🚀 bro trust me done with dinner 100% pls stop send it rn can’t talk rn sure vacay mode at work beach 🏖️ gimme a sec nah brooo same here weekend vibes 😎 omw home cricket 🏏 pizza 🍕 pubg time football match wyd? good morning wait what nope same old basketball 🏀 ice cream 🍦 sunny mood ☀️ road trip 🚗 ugh monday again call u later hey u there? coming soon rainy day 🌧️ ikr good luck 🍀 yep office sucks lol meet u at 5 omg ok cool that’s crazy studying rn 📚 party time valorant match nothing much let’s meet sis ok cool wait what weekend vibes 😎 why u like this lol brb rip she said yes!!! rip let’s meet so bored early morning grind office sucks lol call me later wyd? burger 🍔 movie night sure watching yt guess what? valorant match stuck in traffic gta vibes 🎮 road trip 🚗 can’t stop laughing 😂 brooo long time no see lol ikr be right back basketball 🏀 mountains ⛰️ omg basketball 🏀 sounds good sounds good haha yesss 
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
top5 = list(tokenizer.word_index.items())[:5]
print(top5)
# Out:
# [('u', 1), ('rn', 2), ('let’s', 3), ('good', 4), ('me', 5)]

# %%
total_words = len(tokenizer.word_index)

# %%
import re

def split_on_emojis(text):
    # regex to catch emojis
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags
        u"\U00002700-\U000027BF"  # dingbats
        u"\U0001F900-\U0001F9FF"  # supplemental symbols
        u"\U00002600-\U000026FF"  # misc symbols
        "]+", flags=re.UNICODE
    )
    # split on emoji, keep only non-empty parts
    return [s.strip() for s in emoji_pattern.split(text) if s.strip()]

# %%
input_sequences = []
for sentence in split_on_emojis(faqs):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  # we will create our training dataset from the above tokenized_sentence

  for i in range(1, len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
for seq in input_sequences[:30]:
    print(seq)
# Out:
# [3, 119]
# [3, 119, 17]
# [3, 119, 17, 27]
# [3, 119, 17, 27, 59]
# [3, 119, 17, 27, 59, 60]
# [3, 119, 17, 27, 59, 60, 5]
# [3, 119, 17, 27, 59, 60, 5, 18]
# [3, 119, 17, 27, 59, 60, 5, 18, 120]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121, 122]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121, 122, 161]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121, 122, 161, 28]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121, 122, 161, 28, 3]
# [3, 119, 17, 27, 59, 60, 5, 18, 120, 121, 122, 161, 28, 3, 61]
# [19, 43]
# [19, 43, 5]
# [19, 43, 5, 63]
# [19, 43, 5, 63, 44]
# [19, 43, 5, 63, 44, 123]
# [19, 43, 5, 63, 44, 123, 64]
# [19, 43, 5, 63, 44, 123, 64, 101]
# [19, 43, 5, 63, 44, 123, 64, 101, 29]
# [19, 43, 5, 63, 44, 123, 64, 101, 29, 124]
# [19, 43, 5, 63, 44, 123, 64, 101, 29, 124, 125]
# [19, 43, 5, 63, 44, 123, 64, 101, 29, 124, 125, 2]
# [19, 43, 5, 63, 44, 123, 64, 101, 29, 124, 125, 2, 6]
# [19, 43, 5, 63, 44, 123, 64, 101, 29, 124, 125, 2, 6, 20]
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding = 'pre')
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   3, 119],
#        [  0,   0,   0, ...,   3, 119,  17],
#        [  0,   0,   0, ..., 119,  17,  27],
#        ...,
#        [  0,   0,   0, ...,  57,  55,  10],
#        [  0,   0,   0, ...,   0,  60,   5],
#        [  0,   0,   0, ...,  60,   5,  18]], dtype=int32)

# %%
X = padded_input_sequences[:, :-1]
y = padded_input_sequences[:, -1]

# %%
X.shape
# Out:
# (825, 40)

# %%
y.shape
# Out:
# (825,)

# %%
#oneHotEncoding
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes = total_words+1)

# %%
y.shape
# Out:
# (825, 202)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

# %%
model = Sequential()
model.add(Embedding(input_dim = total_words+1, output_dim = 100))
model.add(LSTM(150))
model.add(Dense(total_words+1, activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer ='adam', metrics = ['accuracy'])
model.build(input_shape = (None, 40))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ (None, 40, 100)        │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 202)            │        30,502 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 201,302 (786.34 KB)
#  Trainable params: 201,302 (786.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs = 100)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.0287 - loss: 5.2762
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.0293 - loss: 4.9931
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.0411 - loss: 4.8774
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.0419 - loss: 4.8674
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.0420 - loss: 4.8341
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.0886 - loss: 4.6792
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.1167 - loss: 4.5342
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.1523 - loss: 4.2938
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.1888 - loss: 4.0502
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.2633 - loss: 3.7027
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.2981 - loss: 3.4347
# ...

# %%
text = 'long time'

# like if you want to predict next five words so run a loop for 5 times
for i in range(10):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  #padding
  padded_token_text = pad_sequences([token_text], maxlen = 40, padding = 'pre')
  #predict
  pos = np.argmax(model.predict(padded_token_text))

  for word, index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# long time no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# long time no see
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# long time no see done
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# long time no see done with
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# long time no see done with dinner
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# long time no see done with dinner idk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# long time no see done with dinner idk pls
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# long time no see done with dinner idk pls stop
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# long time no see done with dinner idk pls stop rainy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# long time no see done with dinner idk pls stop rainy day
